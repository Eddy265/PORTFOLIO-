# %%
import pandas as pd
from pathlib import Path
import statistics
import matplotlib.pyplot as plt
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import timedelta
import plotly.express as px

# %%
df=pd.read_csv('C:/Users/euzoe/OneDrive/Desktop/DATA ANALYSIS/MY_PROJECTS/AppleStore.csv')
df.head()
# Out:
#           id               track_name  size_bytes currency  price  \
# 0  284882215                 Facebook   389879808      USD    0.0
# 1  389801252                Instagram   113954816      USD    0.0
# 2  529479190           Clash of Clans   116476928      USD    0.0
# 3  420009108               Temple Run    65921024      USD    0.0
# 4  284035177  Pandora - Music & Radio   130242560      USD    0.0
#
#    rating_count_tot  rating_count_ver  user_rating  user_rating_ver      ver  \
# 0           2974676               212          3.5              3.5     95.0
# 1           2161558              1289          4.5              4.0    10.23
# 2           2130805               579          4.5              4.5  9.24.12
# 3           1724546              3842          4.5              4.0    1.6.2
# 4           1126879              3594          4.0              4.5    8.4.1
#
#   cont_rating        prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# ...

# %%
df.shape
# Out:
# (7197, 16)

# %%
fil=df.loc[df['user_rating_ver'] >= 5]

# %%
fil.groupby(['track_name']) [['user_rating_ver']].max().sort_values(by=['user_rating_ver'], ascending=False).reset_index()
# Out:
#                               track_name  user_rating_ver
# 0                                 "HOOK"              5.0
# 1                        SayHi Translate              5.0
# 2                     Sky Force Reloaded              5.0
# 3     Sky Guide: View Stars Night or Day              5.0
# 4                    SkyDroid - Golf GPS              5.0
# ..                                   ...              ...
# 959                            Headspace              5.0
# 960  Heuristic Shakespeare - The Tempest              5.0
# 961                     Hide it Hillary!              5.0
# 962               Highlights Monster Day              5.0
# 963                    鬼畜-一亿人都在用的聊天必备神器!              5.0
#
# [964 rows x 2 columns]
